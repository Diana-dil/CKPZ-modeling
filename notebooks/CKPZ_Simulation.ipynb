# %% [markdown]
# # Исследование уравнения CKPZ
# Уравнение роста поверхности:
# $$\partial_t h = -\partial^2 \{ \nu \partial^2 h + (\lambda/2)(\partial_i h)^2 \} + \eta$$

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.operators import laplacian, gradient, get_noise
from src.constants import * # импортируем все наши NU, LAMBDA и т.д.
